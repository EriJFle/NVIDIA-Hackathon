# %% [markdown]
# # Single-cell Analysis Workflow: 1.3M brain cells example
# **Author:** [Severin Dicks](https://github.com/Intron7)

# %% [markdown]
# To run this notebook please make sure you have a working RAPIDS environment with all necessary dependencies. In this example workflow we'll be looking at a dataset of 1.3M brain cells from [10X Genomics](https://www.10xgenomics.com/datasets/1-3-million-brain-cells-from-e-18-mice-2-standard-1-3-0).

# %%
from _rank_genes_groups_wilcoxon import rank_genes_groups_wilcoxon

# %%
import scanpy as sc
import cupy as cp

import time
import rapids_singlecell as rsc

import warnings

warnings.filterwarnings("ignore")

# %%
sc.set_figure_params(dpi_save=300)
sc.settings.verbosity = 3

# %%
print(sc.__version__)
print(rsc.__version__)
print(cp.__version__)
# Out:
# 1.11.2
# 0.12.6
# 13.4.1

# %%
import rmm
from rmm.allocators.cupy import rmm_cupy_allocator

rmm.reinitialize(
    managed_memory=False,  # Allows oversubscription
    pool_allocator=False,  # default is False
    devices=0,  # GPU device IDs to register. By default registers only GPU 0.
)
cp.cuda.set_allocator(rmm_cupy_allocator)

# %%
import gc

# %% [markdown]
# ## Load and Prepare Data

# %% [markdown]
# Let's start by ensuring that we have our dataset downloaded.

# %%
import wget
import os
from anndata.experimental import read_elem_as_dask
import h5py

url = 'https://rapids-single-cell-examples.s3.us-east-2.amazonaws.com/1M_brain_cells_10X.sparse.h5ad'
data_dir = "./h5"
final = data_dir+'/nvidia_1.3M.h5ad'

if not os.path.exists(data_dir): # Check if h5 directory exists
    print('creating data directory')
    os.system('mkdir ./h5')
else:
    print(f'{data_dir} directory found')

if not os.path.isfile(final): # Check to see if we have our final output.  If it is there, get to the analysis!
    print(f'Downloading cell data into {final}...')
    wget.download(url, final)
else:
    print(f'{final} dataset found')
# Out:
# creating data directory
# Downloading cell data into ./h5/nvidia_1.3M.h5ad...

# %% [markdown]
# We load the sparse count matrix from an `h5ad` file using Scanpy. The sparse count matrix will then be placed on the GPU.

# %%
data_load_start = time.time()

# %%
# %%time
adata = sc.read(final)
adata.var_names_make_unique()
adata = adata[:800_000, :].copy()
# Out:
# CPU times: user 1min 24s, sys: 18.2 s, total: 1min 42s
# Wall time: 1min 42s

# %% [markdown]
# We now load the the AnnData object into VRAM.

# %%
# %%time
rsc.get.anndata_to_GPU(adata)
# Out:
# CPU times: user 951 ms, sys: 5.14 s, total: 6.09 s
# Wall time: 6.1 s

# %% [markdown]
# Verify the shape of the resulting sparse matrix:

# %%
adata.shape
# Out:
# (800000, 27998)

# %%
data_load_time = time.time()
print("Total data load and format time: %s" % (data_load_time - data_load_start))
# Out:
# Total data load and format time: 111.00372457504272

# %% [markdown]
# ## Preprocessing

# %%
preprocess_start = time.time()

# %% [markdown]
# ### Quality Control

# %% [markdown]
# We perform a basic qulitiy control and plot the results

# %%
# %%time
rsc.pp.flag_gene_family(adata, gene_family_name="MT", gene_family_prefix="mt-")
# Out:
# CPU times: user 4.72 ms, sys: 228 μs, total: 4.95 ms
# Wall time: 4.83 ms

# %%
# %%time
rsc.pp.calculate_qc_metrics(adata, qc_vars=["MT"])
# Out:
# CPU times: user 921 ms, sys: 19.9 ms, total: 941 ms
# Wall time: 940 ms

# %%
# %%time
sc.pl.scatter(adata, "total_counts", "pct_counts_MT")
sc.pl.scatter(adata, "total_counts", "n_genes_by_counts")
# Out:
# CPU times: user 5.69 s, sys: 4.78 ms, total: 5.69 s
# Wall time: 5.69 s

# %%
# %%time
sc.pl.violin(adata, keys="n_genes_by_counts")
sc.pl.violin(adata, keys="total_counts")
sc.pl.violin(adata, keys="pct_counts_MT")
# Out:
# CPU times: user 15.3 s, sys: 135 ms, total: 15.4 s
# Wall time: 9.66 s

# %% [markdown]
# ### Filter

# %% [markdown]
# We filter the count matrix to remove cells with an extreme number of genes expressed.
# We also filter out cells with a mitchondrial countent of more than 20%.

# %%
# %%time
adata = adata[
    (adata.obs["n_genes_by_counts"] < 5000)
    & (adata.obs["n_genes_by_counts"] > 500)
    & (adata.obs["pct_counts_MT"] < 20)
].copy()
# Out:
# CPU times: user 1.1 s, sys: 56 ms, total: 1.16 s
# Wall time: 1.16 s

# %% [markdown]
# Many python objects are not deallocated until garbage collection runs. When working with data that barely fits in memory (generally, >50%) you may need to manually trigger garbage collection to reclaim memory.

# %%
# %%time
gc.collect()
# Out:
# CPU times: user 119 ms, sys: 7.64 ms, total: 127 ms
# Wall time: 126 ms
# 8120

# %% [markdown]
# We also filter out genes that are expressed in less than 3 cells.

# %%
# %%time
rsc.pp.filter_genes(adata, min_cells=3)
# Out:
# filtered out 5659 genes that are detected in less than 3 cells
# CPU times: user 3.22 s, sys: 79.2 ms, total: 3.3 s
# Wall time: 4.09 s

# %% [markdown]
# We store the raw expression counts in the `.layer["counts"]`

# %%
adata.layers["counts"] = adata.X.copy()

# %%
adata.shape
# Out:
# (786908, 22339)

# %% [markdown]
# ### Normalize

# %% [markdown]
# We normalize the count matrix so that the total counts in each cell sum to 1e4.

# %%
# %%time
rsc.pp.normalize_total(adata, target_sum=1e4)
# Out:
# CPU times: user 49.4 ms, sys: 335 μs, total: 49.7 ms
# Wall time: 49.5 ms

# %% [markdown]
# Next, we log transform the count matrix.

# %%
# %%time
rsc.pp.log1p(adata)
# Out:
# CPU times: user 92.8 ms, sys: 11.9 ms, total: 105 ms
# Wall time: 283 ms

# %% [markdown]
# ### Select Most Variable Genes

# %% [markdown]
# Now we search for highly variable genes. This function only supports the flavors `cell_ranger` `seurat` `seurat_v3` and `pearson_residuals`. As you can in scanpy you can filter based on cutoffs or select the top n cells. You can also use a `batch_key` to reduce batcheffects.

# %% [markdown]
# In this example we use `seurat_v3` for selecting highly variable genes based on the raw counts in `.layer["counts"]`.

# %%
# %%time
rsc.pp.highly_variable_genes(
    adata, n_top_genes=5000, flavor="seurat_v3", layer="counts"
)
# Out:
# CPU times: user 6.77 s, sys: 232 ms, total: 7 s
# Wall time: 7 s

# %%
# %%time
rsc.get.anndata_to_CPU(adata, layer="counts")
# Out:
# CPU times: user 1.85 s, sys: 1.62 s, total: 3.47 s
# Wall time: 3.47 s

# %% [markdown]
# Now we safe this version of the AnnData as adata.raw.

# %%
# %%time
adata.raw = adata
# Out:
# CPU times: user 1.72 s, sys: 1.7 s, total: 3.42 s
# Wall time: 3.42 s

# %% [markdown]
# Now we restrict our AnnData object to the highly variable genes.

# %%
# %%time
adata = adata[:, adata.var["highly_variable"]]
# Out:
# CPU times: user 1.44 s, sys: 1.93 s, total: 3.38 s
# Wall time: 3.38 s

# %%
adata.shape
# Out:
# (786908, 5000)

# %% [markdown]
# Next we regress out effects of counts per cell and the mitochondrial content of the cells. As you can with scanpy you can use every numerical column in `.obs` for this.

# %%
# %%time
rsc.pp.regress_out(adata, keys=["total_counts", "pct_counts_MT"])
# Out:
# CPU times: user 11.5 s, sys: 3.23 s, total: 14.7 s
# Wall time: 15.4 s

# %% [markdown]
# ### Scale

# %% [markdown]
# Finally, we scale the count matrix to obtain a z-score and apply a cutoff value of 10 standard deviations.

# %%
# %%time
rsc.pp.scale(adata, max_value=10)
# Out:
# CPU times: user 2.9 s, sys: 119 ms, total: 3.02 s
# Wall time: 3.02 s

# %% [markdown]
# ### Principal component analysis

# %% [markdown]
# We use PCA to reduce the dimensionality of the matrix to its top 100 principal components. We use the PCA implementation from cuml to run this. With `use_highly_variable = False` we save VRAM since we already subset the matrix to only HVGs.

# %%
# %%time
rsc.pp.pca(adata, n_comps=100, use_highly_variable=False)
# Out:
# CPU times: user 4.12 s, sys: 149 ms, total: 4.27 s
# Wall time: 5.08 s

# %% [markdown]
# We can use scanpy `pca_variance_ratio` plot to inspect the contribution of single PCs to the total variance in the data.

# %%
sc.pl.pca_variance_ratio(adata, log=True, n_pcs=100)

# %% [markdown]
# Now we move `.X` and `.layers` out of the GPU.

# %%
# %%time
rsc.get.anndata_to_CPU(adata)
# Out:
# CPU times: user 2.25 s, sys: 2.03 s, total: 4.28 s
# Wall time: 4.3 s

# %%
preprocess_time = time.time()
print("Total Preprocessing time: %s" % (preprocess_time - preprocess_start))
# Out:
# Total Preprocessing time: 68.58495450019836

# %% [markdown]
# Visualization## Clustering and Visualization

# %% [markdown]
# ### Computing the neighborhood graph and UMAP

# %% [markdown]
# Next we compute the neighborhood graph using rsc.
#
# Scanpy CPU implementation of nearest neighbor uses an approximation, while the GPU version calculates the exact graph. Both methods are valid, but you might see differences.

# %%
# %%time
rsc.pp.neighbors(adata, n_neighbors=15, n_pcs=50)
# Out:
# CPU times: user 14.8 s, sys: 374 ms, total: 15.2 s
# Wall time: 15.2 s

# %% [markdown]
# Next we calculate the UMAP embedding using rapdis.

# %%
# %%time
rsc.tl.umap(adata, min_dist=0.3)
# Out:
# CPU times: user 2.69 s, sys: 220 ms, total: 2.91 s
# Wall time: 2.91 s

# %% [markdown]
# ### Clustering

# %% [markdown]
# Next, we use the Louvain and Leiden algorithm for graph-based clustering.

# %%
# %%time
rsc.tl.louvain(adata, resolution=0.6)
# Out:
# CPU times: user 2.09 s, sys: 5.02 s, total: 7.11 s
# Wall time: 7.33 s

# %%
# %%time
rsc.tl.leiden(adata, resolution=1.0)
# Out:
# CPU times: user 1.68 s, sys: 4.2 s, total: 5.88 s
# Wall time: 5.89 s

# %%
# %%time
sc.pl.umap(adata, color=["louvain", "leiden"], legend_loc="on data")
# Out:
# CPU times: user 6.87 s, sys: 57.2 ms, total: 6.92 s
# Wall time: 6.92 s

# %% [markdown]
# ## TSNE

# %%
# %%time
rsc.tl.tsne(adata, n_pcs=40)
# Out:
# [2025-09-25 01:40:29.947] [CUML] [warning] # of Nearest Neighbors should be at least 3 * perplexity. Your results might be a bit strange...
# CPU times: user 17 s, sys: 6.41 s, total: 23.4 s
# Wall time: 23.3 s

# %%
sc.pl.tsne(adata, color=["louvain", "leiden"], legend_loc="on data")

# %% [markdown]
# ## Differential expression analysis

# %% [markdown]
# We now use logistic regression to compute a ranking for highly differential genes in each Louvaincluster.

# %%
# %%time
rsc.tl.rank_genes_groups_logreg(adata, groupby="leiden", use_raw=False)
# Out:
# [2025-09-25 01:42:28.222] [CUML] [warning] L-BFGS: max iterations reached
# [2025-09-25 01:42:28.393] [CUML] [warning] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# CPU times: user 1min 4s, sys: 19.6 s, total: 1min 24s
# Wall time: 1min 24s

# %%
# %%time
sc.pl.rank_genes_groups_dotplot(
    adata,
    groupby="leiden",
    n_genes=3,
    use_raw=False,
    standard_scale="var",
    cmap="Purples",
    save="800k_gpu_rank_genes_logreg.png",
)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_leiden). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
#     using 'X_pca' with n_pcs = 100
# Storing dendrogram info using `.uns['dendrogram_leiden']`
# WARNING: saving figure to file figures/dotplot_800k_gpu_rank_genes_logreg.png
# CPU times: user 6.39 s, sys: 696 ms, total: 7.09 s
# Wall time: 7.09 s

# %%
# %%time
rank_genes_groups_wilcoxon(
    adata,
    groupby="leiden",
    use_raw=False,
    tie_correct=False,
)
# Out:
# CPU times: user 19.7 s, sys: 21.3 s, total: 41.1 s
# Wall time: 42 s

# %%
# %%time
sc.pl.rank_genes_groups_dotplot(
    adata,
    groupby="leiden",
    n_genes=3,
    use_raw=False,
    standard_scale="var",
    cmap="Purples",
    save="800k_gpu_rank_genes_wilcoxon.png",
)
# Out:
# WARNING: saving figure to file figures/dotplot_800k_gpu_rank_genes_wilcoxon.png
# CPU times: user 5.5 s, sys: 566 ms, total: 6.07 s
# Wall time: 6.07 s

# %%
gc.collect()
# Out:
# 63307

# %%
# %%time
sc.tl.rank_genes_groups(
    adata,
    groupby="leiden",
    use_raw=False,
    tie_correct=False,
    method="wilcoxon",
    key_added="cpu_ranks",
)
# Out:
# ranking genes
#     finished: added to `.uns['cpu_ranks']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:10:15)
# CPU times: user 24min 8s, sys: 2min 58s, total: 27min 6s
# Wall time: 10min 15s

# %%
# %%time
sc.pl.rank_genes_groups_dotplot(
    adata,
    groupby="leiden",
    n_genes=3,
    use_raw=False,
    standard_scale="var",
    cmap="Purples",
    key="cpu_ranks",
    save="800k_cpu_rank_genes_wilcoxon.png",
)
# Out:
# WARNING: saving figure to file figures/dotplot_800k_cpu_rank_genes_wilcoxon.png
# CPU times: user 4.85 s, sys: 540 ms, total: 5.39 s
# Wall time: 5.39 s

# %%
cpu_res = adata.uns["cpu_ranks"].copy()
gpu_res = adata.uns["rank_genes_groups"].copy()

cpu_scores = cpu_res["scores"]
gpu_scores = gpu_res["scores"]

# %%
import numpy as np
for group in cpu_scores.dtype.names:
    a = cpu_scores[group]
    b = gpu_scores[group]

    np.testing.assert_array_equal(a, b)

    identical = np.array_equal(a, b)
    print(f"{group}: {'match' if identical else 'DIFFER'}")
# Out:
# 0: match
# 1: match
# 2: match
# 3: match
# 4: match
# 5: match
# 6: match
# 7: match
# 8: match
# 9: match
# 10: match
# 11: match
# 12: match
# 13: match
# 14: match
# 15: match
# 16: match
# 17: match
# 18: match
# 19: match
# 20: match
# 21: match
# 22: match
# 23: match
# 24: match
# 25: match
# 26: match
# 27: match
# 28: match
# 29: match
# 30: match
# 31: match
# 32: match
# 33: match
# 34: match
